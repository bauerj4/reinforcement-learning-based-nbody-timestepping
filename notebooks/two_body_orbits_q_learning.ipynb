# %% [markdown]
# # Orbit Energies for 2-Body Problem
#
# This notebook generates plots for my study of Q-Learning applied to the 2-body problem.
#
# ## Baseline: Fixed Timestep for Integration
#
# Make plots to establish a baseline for the problem.

# %%
import pandas as pd
import os

# Data directories
data_dir = "../data/"
euler_circular_baseline = "big_body_small_body_circular_euler_fixed_timestep" #"two_body_euler_circular_fixed_timestep"
leapfrog_order_1_circular_baseline = "big_body_small_body_circular_leapfrog_1_fixed_timestep" #"two_body_leapfrog_1_circular_fixed_timestep"
leapfrog_order_2_circular_baseline = "big_body_small_body_circular_leapfrog_2_fixed_timestep" #"two_body_leapfrog_2_circular_fixed_timestep"

# Load energies

euler_circular_baseline_energies = pd.read_csv(
    os.path.join(data_dir, euler_circular_baseline, "0.energies.dat"),
    names=["Time (Gyr)", "Min Timestep (Gyr)", "Energy (G=1 units)", "Acceleration calculations"]
)

leapfrog_order_1_circular_baseline_energies = pd.read_csv(
    os.path.join(data_dir, leapfrog_order_1_circular_baseline, "0.energies.dat"),
    names=["Time (Gyr)", "Min Timestep (Gyr)", "Energy (G=1 units)", "Acceleration calculations"]
)

leapfrog_order_2_circular_baseline_energies = pd.read_csv(
    os.path.join(data_dir, leapfrog_order_2_circular_baseline, "0.energies.dat"),
    names=["Time (Gyr)", "Min Timestep (Gyr)", "Energy (G=1 units)", "Acceleration calculations"]
)

# Load particles
euler_circular_baseline_p1 = pd.read_csv(
    os.path.join(data_dir, euler_circular_baseline, "episode.particle.0.0.dat"),
    names=["Time (Gyr)", "x", "y", "z", "vx", "vy", "vz", "ax", "ay", "az"]
)

leapfrog_order_1_circular_baseline_p1 = pd.read_csv(
    os.path.join(data_dir, leapfrog_order_1_circular_baseline, "episode.particle.0.0.dat"),
    names=["Time (Gyr)", "x", "y", "z", "vx", "vy", "vz", "ax", "ay", "az"]
)

leapfrog_order_2_circular_baseline_p1 = pd.read_csv(
    os.path.join(data_dir, leapfrog_order_2_circular_baseline, "episode.particle.0.0.dat"),
    names=["Time (Gyr)", "x", "y", "z", "vx", "vy", "vz", "ax", "ay", "az"]
)

# %%
import matplotlib.pylab as plt
import numpy as np

# T = 2 pi sqrt(r**3 / GM)
euler_circular_relative_energies = abs(euler_circular_baseline_energies["Energy (G=1 units)"] - euler_circular_baseline_energies["Energy (G=1 units)"][0]) / -euler_circular_baseline_energies["Energy (G=1 units)"][0]
leapfrog_order_1_circular_relative_energies = abs(leapfrog_order_1_circular_baseline_energies["Energy (G=1 units)"] - leapfrog_order_1_circular_baseline_energies["Energy (G=1 units)"][0]) / -leapfrog_order_1_circular_baseline_energies["Energy (G=1 units)"][0]
leapfrog_order_2_circular_relative_energies = abs(leapfrog_order_2_circular_baseline_energies["Energy (G=1 units)"] - leapfrog_order_2_circular_baseline_energies["Energy (G=1 units)"][0]) / -leapfrog_order_2_circular_baseline_energies["Energy (G=1 units)"][0]

# euler_circular_relative_energies = abs(euler_circular_baseline_energies["Energy (G=1 units)"]) / -euler_circular_baseline_energies["Energy (G=1 units)"][0]
# leapfrog_order_1_circular_relative_energies = abs(leapfrog_order_1_circular_baseline_energies["Energy (G=1 units)"]) / -leapfrog_order_1_circular_baseline_energies["Energy (G=1 units)"][0]
# leapfrog_order_2_circular_relative_energies = abs(leapfrog_order_2_circular_baseline_energies["Energy (G=1 units)"]) / -leapfrog_order_2_circular_baseline_energies["Energy (G=1 units)"][0]

# euler_circular_relative_energies = abs(euler_circular_baseline_energies["Energy (G=1 units)"])
# leapfrog_order_1_circular_relative_energies = abs(leapfrog_order_1_circular_baseline_energies["Energy (G=1 units)"]) 
# leapfrog_order_2_circular_relative_energies = abs(leapfrog_order_2_circular_baseline_energies["Energy (G=1 units)"]) 

plt.plot(leapfrog_order_2_circular_baseline_energies["Time (Gyr)"], leapfrog_order_2_circular_relative_energies)
plt.plot(leapfrog_order_1_circular_baseline_energies["Time (Gyr)"], leapfrog_order_1_circular_relative_energies)
plt.plot(euler_circular_baseline_energies["Time (Gyr)"], euler_circular_relative_energies)

plt.yscale("log")
leapfrog_order_1_circular_baseline_energies["Time (Gyr)"]
# Out:
# 0         0.0005
# 1         0.0010
# 2         0.0015
# 3         0.0020
# 4         0.0025
#           ...
# 99995    49.9980
# 99996    49.9985
# 99997    49.9990
# 99998    49.9995
# 99999    50.0000
# Name: Time (Gyr), Length: 100000, dtype: float64

# %%
#plt.plot(euler_circular_baseline_p1['x'], euler_circular_baseline_p1['y'])
plt.plot(leapfrog_order_1_circular_baseline_p1['x'], leapfrog_order_1_circular_baseline_p1['y'])
plt.plot(leapfrog_order_2_circular_baseline_p1['x'], leapfrog_order_2_circular_baseline_p1['y'])
# circle = plt.Circle((0, 0), 50, fill=False, color="red")
# plt.gca().add_patch(circle)

# %%
plt.plot(
    leapfrog_order_1_circular_baseline_energies["Time (Gyr)"],
    (euler_circular_baseline_p1['x']**2 + euler_circular_baseline_p1['y']**2 + euler_circular_baseline_p1['z']**2)**0.5,
)
plt.plot(
    leapfrog_order_1_circular_baseline_energies["Time (Gyr)"],
    (leapfrog_order_1_circular_baseline_p1['x']**2 + leapfrog_order_1_circular_baseline_p1['y']**2 + leapfrog_order_1_circular_baseline_p1['z']**2)**0.5,
)
plt.plot(
    leapfrog_order_1_circular_baseline_energies["Time (Gyr)"],
    (leapfrog_order_2_circular_baseline_p1['x']**2 + leapfrog_order_2_circular_baseline_p1['y']**2 + leapfrog_order_2_circular_baseline_p1['z']**2)**0.5
)
